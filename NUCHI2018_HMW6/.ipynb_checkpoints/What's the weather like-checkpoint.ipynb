# %%
# Dependencies for Weather
import requests as req
import openweathermapy.core as owm
from citipy import citipy
#Dependencies for random coordinates
import random
from random import uniform
#Dependencies for Df and Analysis
import numpy as np
import pandas as pd
#Dependencies for Plots
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
#Dependencies for api key
from config import api_key

# %%
#Define max value for the initial range and sample size
max_coord = 1500
sample = 500

# %%
#Generate random latitude coordinates with a function
def lat_coordinates():
    return random.uniform(-90,90)
random_lat_coord = [lat_coordinates() for latitude in range(max_coord)]
#random_lat_coord[0]
#Generate random longitude coordinates with a function
def long_coordinates():
    return random.uniform(-180,180)
random_long_coord = [long_coordinates() for longitude in range(max_coord)]
#random_long_coord[0]
#len(random_long_coord)
#len(random_lat_coord)

# %%
# Functions to remove duplicated elements.I decided not to use this here because of future merging problems in the DF
#test the function random_lat_coord = [2,2,3,4,4,8]
#def Remove(_):
    #latitude_coord = []
    #for coordenate in random_lat_coord:
        #if coordenate not in latitude_coord:
            #latitude_coord.append(coordenate)
    #return latitude_coord
#latitude = Remove(random_lat_coord)
#latitude

#def Remove(_):
    #longitude_coord = []
    #for coordenate in random_long_coord:
        #if coordenate not in longitude_coord:
            #longitude_coord.append(coordenate)
    #return longitude_coord
#longitude = Remove(random_lat_coord)
#longitude

# %%
#Rename the coordenates list 
latitude = random_lat_coord
longitude = random_long_coord

# %%
#Test the function to return city and country
#city= citipy.nearest_city(latitude[0],longitude[0])
#city
#city.city_name
#city.country_code

# %%
#Generate city names for the lat and long coordenates above
city_names = []
for x in range(0,max_coord):
    city_name = citipy.nearest_city(latitude[x],longitude[x])
    city_names.append(city_name)
#city_names

#Generate the city and country lists 
city_list = []
for x in range(0,max_coord):
    city = city_names[x].city_name
    #print(city_names[x].city_name)
    city_list.append(city)

country_list = []
for y in range(0,max_coord):
    country = city_names[y].country_code
    #print(city_names[y].country_code)
    country_list.append(country)

#Generate Dataframe
location_df = pd.DataFrame()

location_df["Latitude"] = ""
location_df["Longitude"] = ""
location_df['City'] = ''
location_df['Country Code'] = ''
location_df = location_df.append(pd.DataFrame.from_dict({"Latitude":latitude,"Longitude":longitude,"City":city_list,"Country Code":country_list,}))
location_df = location_df.reset_index(drop=True)
location_df.shape
#location_df

#Clean the data, drop the duplicated citites and reindex
drop_location_df = location_df.drop_duplicates(['City'])
drop_location_df.shape
new_location_df = drop_location_df.sample(sample)
city_coordinates_df = new_location_df.reset_index(drop=True)

#See the random coordenates in the map for the nearest cities:
import cartopy.crs as ccrs

fig, ax = plt.subplots(figsize = (20,10))

ax = plt.axes(projection=ccrs.PlateCarree())
ax.stock_img()

plt.scatter(list(city_coordinates_df['Longitude']),list(city_coordinates_df['Latitude']), color='red', marker = 'x', transform = ccrs.Geodetic(),)

plt.title('Distribution of 500 random cities')
plt.savefig('50 Cities in the world')
plt.show()

# %%
#Set the URL
url = "http://api.openweathermap.org/data/2.5/weather?"

#Set the parameters
units = 'imperial'
settings = {"units":"imperial", "appid" :api_key}

# %%
# Testing the api_key -> Get current weather for first city in the initial city list
try:
    current_weather = owm.get_current(city_list[0], **settings)
    print("Current temperature (F) for %s:" %(city_list[0]).capitalize())
    print(current_weather['main']['temp'])
except:
    print('HTTP Error: Not Found')
# Out:
# Current temperature (F) for Port elizabeth:
# 48.25

# %%
#city_coordinates_df.head()

# %%
#Requesting weather data for all the cities in the list. I should iterate through all the list
for index, row in city_coordinates_df.iterrows():    
    
    #Set parameters for the query
    city = row['City']
    country = row['Country Code']
    settings['q'] =f"{city},{country}"
    
    #Query the url
    #query_url = "%s%sappid=%s&units=%s&q="%(url,api_key,units,city)
    query_url = f"{url}appid={api_key}&units={units}&q="
    
    # Request information to the endpoint and prit response
    print(f"Retrieve Weather Parameters for: {settings['q']}")
    WeatherPy_response = req.get(query_url + city)
    print(WeatherPy_response.url)
    
    #Create json response
    WeatherPy_response  = WeatherPy_response.json()
    
    #Set values for Temperature, Humidity, Cloudiness, Wind Speed, Latitude and Longitude
    city_coordinates_df.set_value(index,"Temperature",WeatherPy_response.get("main",{}).get("temp_max"))
    city_coordinates_df.set_value(index,"Humidity",WeatherPy_response.get("main",{}).get("humidity"))
    city_coordinates_df.set_value(index,"Cloudiness",WeatherPy_response.get("clouds",{}).get("all"))
    city_coordinates_df.set_value(index,"Wind Speed",WeatherPy_response.get("wind",{}).get("speed"))
    city_coordinates_df.set_value(index,"Latitude",WeatherPy_response.get("coord",{}).get("lat"))
    city_coordinates_df.set_value(index,"Longitude",WeatherPy_response.get("coord",{}).get("lon"))
# Out:
# Retrieve Weather Parameters for: kirakira,sb
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kirakira
# Retrieve Weather Parameters for: nishihara,jp
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=nishihara
# Retrieve Weather Parameters for: kruisfontein,za
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kruisfontein
# Retrieve Weather Parameters for: elizabeth city,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=elizabeth%20city
# Retrieve Weather Parameters for: te anau,nz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=te%20anau
# Retrieve Weather Parameters for: cunduacan,mx
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=cunduacan
# Retrieve Weather Parameters for: komsomolskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=komsomolskiy
# Retrieve Weather Parameters for: mao,td
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mao
# Retrieve Weather Parameters for: marcona,pe
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=marcona
# Retrieve Weather Parameters for: hobyo,so
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=hobyo
# Retrieve Weather Parameters for: roald,no
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=roald
# Retrieve Weather Parameters for: port hedland,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=port%20hedland
# Retrieve Weather Parameters for: ribeira grande,pt
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ribeira%20grande
# Retrieve Weather Parameters for: progreso,mx
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=progreso
# Retrieve Weather Parameters for: coracora,pe
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=coracora
# Retrieve Weather Parameters for: sahibganj,in
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=sahibganj
# Retrieve Weather Parameters for: bajo baudo,co
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=bajo%20baudo
# Retrieve Weather Parameters for: cherskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=cherskiy
# Retrieve Weather Parameters for: carinhanha,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=carinhanha
# Retrieve Weather Parameters for: los llanos de aridane,es
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=los%20llanos%20de%20aridane
# Retrieve Weather Parameters for: samarai,pg
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=samarai
# Retrieve Weather Parameters for: christchurch,nz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=christchurch
# Retrieve Weather Parameters for: flinders,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=flinders
# Retrieve Weather Parameters for: halalo,wf
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=halalo
# Retrieve Weather Parameters for: kavieng,pg
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kavieng
# Retrieve Weather Parameters for: mbanza-ngungu,cd
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mbanza-ngungu
# Retrieve Weather Parameters for: jacareacanga,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=jacareacanga
# Retrieve Weather Parameters for: izumo,jp
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=izumo
# Retrieve Weather Parameters for: nome,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=nome
# Retrieve Weather Parameters for: opuwo,na
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=opuwo
# Retrieve Weather Parameters for: jiuquan,cn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=jiuquan
# Retrieve Weather Parameters for: louisbourg,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=louisbourg
# Retrieve Weather Parameters for: frontera,mx
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=frontera
# Retrieve Weather Parameters for: lambarene,ga
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=lambarene
# Retrieve Weather Parameters for: baghdad,iq
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=baghdad
# Retrieve Weather Parameters for: montrose,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=montrose
# Retrieve Weather Parameters for: burnie,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=burnie
# Retrieve Weather Parameters for: kandalaksha,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kandalaksha
# Retrieve Weather Parameters for: sur,om
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=sur
# Retrieve Weather Parameters for: lucea,jm
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=lucea
# Retrieve Weather Parameters for: ambon,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ambon
# Retrieve Weather Parameters for: gat,ly
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=gat
# Retrieve Weather Parameters for: matara,lk
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=matara
# Retrieve Weather Parameters for: baruun-urt,mn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=baruun-urt
# Retrieve Weather Parameters for: atuona,pf
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=atuona
# Retrieve Weather Parameters for: provideniya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=provideniya
# Retrieve Weather Parameters for: tabou,ci
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=tabou
# Retrieve Weather Parameters for: isangel,vu
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=isangel
# Retrieve Weather Parameters for: ajra,in
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ajra
# Retrieve Weather Parameters for: otradnyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=otradnyy
# Retrieve Weather Parameters for: temaraia,ki
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=temaraia
# Retrieve Weather Parameters for: busselton,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=busselton
# Retrieve Weather Parameters for: camacha,pt
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=camacha
# Retrieve Weather Parameters for: marzuq,ly
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=marzuq
# Retrieve Weather Parameters for: koslan,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=koslan
# Retrieve Weather Parameters for: bredasdorp,za
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=bredasdorp
# Retrieve Weather Parameters for: saravan,la
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=saravan
# Retrieve Weather Parameters for: pangai,to
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=pangai
# Retrieve Weather Parameters for: ostrovnoy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ostrovnoy
# Retrieve Weather Parameters for: kidal,ml
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kidal
# Retrieve Weather Parameters for: manzil salim,tn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=manzil%20salim
# Retrieve Weather Parameters for: rocha,uy
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=rocha
# Retrieve Weather Parameters for: ambilobe,mg
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ambilobe
# Retrieve Weather Parameters for: pisco,pe
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=pisco
# Retrieve Weather Parameters for: mouzakion,gr
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mouzakion
# Retrieve Weather Parameters for: tasiilaq,gl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=tasiilaq
# Retrieve Weather Parameters for: port elizabeth,za
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=port%20elizabeth
# Retrieve Weather Parameters for: pokrovskoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=pokrovskoye
# Retrieve Weather Parameters for: sakaiminato,jp
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=sakaiminato
# Retrieve Weather Parameters for: virginia beach,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=virginia%20beach
# Retrieve Weather Parameters for: biak,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=biak
# Retrieve Weather Parameters for: hofn,is
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=hofn
# Retrieve Weather Parameters for: vuktyl,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=vuktyl
# Retrieve Weather Parameters for: sfantu gheorghe,ro
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=sfantu%20gheorghe
# Retrieve Weather Parameters for: oriximina,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=oriximina
# Retrieve Weather Parameters for: dudinka,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=dudinka
# Retrieve Weather Parameters for: poum,nc
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=poum
# Retrieve Weather Parameters for: yellowknife,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=yellowknife
# Retrieve Weather Parameters for: albany,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=albany
# Retrieve Weather Parameters for: vanimo,pg
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=vanimo
# Retrieve Weather Parameters for: megion,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=megion
# Retrieve Weather Parameters for: severo-kurilsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=severo-kurilsk
# Retrieve Weather Parameters for: bundaberg,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=bundaberg
# Retrieve Weather Parameters for: mezen,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mezen
# Retrieve Weather Parameters for: belaya gora,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=belaya%20gora
# Retrieve Weather Parameters for: coihaique,cl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=coihaique
# Retrieve Weather Parameters for: kayerkan,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kayerkan
# Retrieve Weather Parameters for: kimberley,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kimberley
# Retrieve Weather Parameters for: taltal,cl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=taltal
# Retrieve Weather Parameters for: bilma,ne
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=bilma
# Retrieve Weather Parameters for: aban,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=aban
# Retrieve Weather Parameters for: lypova dolyna,ua
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=lypova%20dolyna
# Retrieve Weather Parameters for: ahar,ir
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ahar
# Retrieve Weather Parameters for: ahipara,nz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ahipara
# Retrieve Weather Parameters for: santa cruz,cr
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=santa%20cruz
# Retrieve Weather Parameters for: aitape,pg
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=aitape
# Retrieve Weather Parameters for: sioux lookout,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=sioux%20lookout
# Retrieve Weather Parameters for: atar,mr
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=atar
# Retrieve Weather Parameters for: mataura,pf
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mataura
# Retrieve Weather Parameters for: port macquarie,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=port%20macquarie
# Retrieve Weather Parameters for: sambava,mg
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=sambava
# Retrieve Weather Parameters for: udachnyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=udachnyy
# Retrieve Weather Parameters for: tuatapere,nz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=tuatapere
# Retrieve Weather Parameters for: jambi,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=jambi
# Retrieve Weather Parameters for: fershampenuaz,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=fershampenuaz
# Retrieve Weather Parameters for: rio grande,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=rio%20grande
# Retrieve Weather Parameters for: toora-khem,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=toora-khem
# Retrieve Weather Parameters for: zeya,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=zeya
# Retrieve Weather Parameters for: toulepleu,ci
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=toulepleu
# Retrieve Weather Parameters for: valenca,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=valenca
# Retrieve Weather Parameters for: bakel,sn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=bakel
# Retrieve Weather Parameters for: strezhevoy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=strezhevoy
# Retrieve Weather Parameters for: havoysund,no
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=havoysund
# Retrieve Weather Parameters for: vao,nc
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=vao
# Retrieve Weather Parameters for: kavaratti,in
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kavaratti
# Retrieve Weather Parameters for: lubango,ao
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=lubango
# Retrieve Weather Parameters for: ust-kamchatsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ust-kamchatsk
# Retrieve Weather Parameters for: nabire,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=nabire
# Retrieve Weather Parameters for: yulara,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=yulara
# Retrieve Weather Parameters for: north bend,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=north%20bend
# Retrieve Weather Parameters for: szolnok,hu
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=szolnok
# Retrieve Weather Parameters for: boa vista,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=boa%20vista
# Retrieve Weather Parameters for: danielskuil,za
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=danielskuil
# Retrieve Weather Parameters for: pendleton,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=pendleton
# Retrieve Weather Parameters for: adre,td
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=adre
# Retrieve Weather Parameters for: dolbeau,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=dolbeau
# Retrieve Weather Parameters for: port lincoln,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=port%20lincoln
# Retrieve Weather Parameters for: buerarema,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=buerarema
# Retrieve Weather Parameters for: fort saint john,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=fort%20saint%20john
# Retrieve Weather Parameters for: kingisepp,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kingisepp
# Retrieve Weather Parameters for: ulaangom,mn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ulaangom
# Retrieve Weather Parameters for: coquimbo,cl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=coquimbo
# Retrieve Weather Parameters for: dawei,mm
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=dawei
# Retrieve Weather Parameters for: sao jose da coroa grande,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=sao%20jose%20da%20coroa%20grande
# Retrieve Weather Parameters for: kaitangata,nz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kaitangata
# Retrieve Weather Parameters for: yusva,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=yusva
# Retrieve Weather Parameters for: cape town,za
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=cape%20town
# Retrieve Weather Parameters for: inuvik,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=inuvik
# Retrieve Weather Parameters for: kamenskoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kamenskoye
# Retrieve Weather Parameters for: ushtobe,kz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ushtobe
# Retrieve Weather Parameters for: tra vinh,vn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=tra%20vinh
# Retrieve Weather Parameters for: mar del plata,ar
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mar%20del%20plata
# Retrieve Weather Parameters for: toliary,mg
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=toliary
# Retrieve Weather Parameters for: chagda,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=chagda
# Retrieve Weather Parameters for: stoyba,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=stoyba
# Retrieve Weather Parameters for: malanje,ao
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=malanje
# Retrieve Weather Parameters for: mambolo,sl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mambolo
# Retrieve Weather Parameters for: tual,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=tual
# Retrieve Weather Parameters for: cumaribo,co
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=cumaribo
# Retrieve Weather Parameters for: ancud,cl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ancud
# Retrieve Weather Parameters for: puerto quijarro,bo
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=puerto%20quijarro
# Retrieve Weather Parameters for: barbalha,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=barbalha
# Retrieve Weather Parameters for: tynset,no
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=tynset
# Retrieve Weather Parameters for: turukhansk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=turukhansk
# Retrieve Weather Parameters for: hervey bay,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=hervey%20bay
# Retrieve Weather Parameters for: viedma,ar
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=viedma
# Retrieve Weather Parameters for: yeppoon,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=yeppoon
# Retrieve Weather Parameters for: maniitsoq,gl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=maniitsoq
# Retrieve Weather Parameters for: san policarpo,ph
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=san%20policarpo
# Retrieve Weather Parameters for: sungaipenuh,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=sungaipenuh
# Retrieve Weather Parameters for: nagato,jp
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=nagato
# Retrieve Weather Parameters for: gidole,et
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=gidole
# Retrieve Weather Parameters for: acapulco,mx
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=acapulco
# Retrieve Weather Parameters for: saint-georges,gf
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=saint-georges
# Retrieve Weather Parameters for: hualmay,pe
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=hualmay
# Retrieve Weather Parameters for: chuy,uy
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=chuy
# Retrieve Weather Parameters for: selma,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=selma
# Retrieve Weather Parameters for: saleaula,ws
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=saleaula
# Retrieve Weather Parameters for: urengoy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=urengoy
# Retrieve Weather Parameters for: mahebourg,mu
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mahebourg
# Retrieve Weather Parameters for: butaritari,ki
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=butaritari
# Retrieve Weather Parameters for: kananga,cd
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kananga
# Retrieve Weather Parameters for: kula,bg
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kula
# Retrieve Weather Parameters for: usinsk,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=usinsk
# Retrieve Weather Parameters for: akdepe,tm
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=akdepe
# Retrieve Weather Parameters for: shediac,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=shediac
# Retrieve Weather Parameters for: iskateley,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=iskateley
# Retrieve Weather Parameters for: esperance,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=esperance
# Retrieve Weather Parameters for: bur gabo,so
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=bur%20gabo
# Retrieve Weather Parameters for: tarakan,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=tarakan
# Retrieve Weather Parameters for: sorong,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=sorong
# Retrieve Weather Parameters for: paradwip,in
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=paradwip
# Retrieve Weather Parameters for: portland,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=portland
# Retrieve Weather Parameters for: hermanus,za
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=hermanus
# Retrieve Weather Parameters for: bluff,nz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=bluff
# Retrieve Weather Parameters for: matamoros,mx
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=matamoros
# Retrieve Weather Parameters for: upernavik,gl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=upernavik
# Retrieve Weather Parameters for: saskylakh,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=saskylakh
# Retrieve Weather Parameters for: hovd,mn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=hovd
# Retrieve Weather Parameters for: la macarena,co
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=la%20macarena
# Retrieve Weather Parameters for: ongandjera,na
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ongandjera
# Retrieve Weather Parameters for: mumford,gh
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mumford
# Retrieve Weather Parameters for: phan rang,vn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=phan%20rang
# Retrieve Weather Parameters for: amiens,fr
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=amiens
# Retrieve Weather Parameters for: awbari,ly
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=awbari
# Retrieve Weather Parameters for: niquero,cu
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=niquero
# Retrieve Weather Parameters for: numan,ng
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=numan
# Retrieve Weather Parameters for: vaini,to
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=vaini
# Retrieve Weather Parameters for: natal,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=natal
# Retrieve Weather Parameters for: yar-sale,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=yar-sale
# Retrieve Weather Parameters for: manjo,cm
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=manjo
# Retrieve Weather Parameters for: kukushtan,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kukushtan
# Retrieve Weather Parameters for: santiago,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=santiago
# Retrieve Weather Parameters for: praia da vitoria,pt
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=praia%20da%20vitoria
# Retrieve Weather Parameters for: doha,kw
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=doha
# Retrieve Weather Parameters for: nikolskoye,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=nikolskoye
# Retrieve Weather Parameters for: mehamn,no
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mehamn
# Retrieve Weather Parameters for: aksarka,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=aksarka
# Retrieve Weather Parameters for: henties bay,na
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=henties%20bay
# Retrieve Weather Parameters for: batagay-alyta,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=batagay-alyta
# Retrieve Weather Parameters for: liuhe,cn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=liuhe
# Retrieve Weather Parameters for: yanam,in
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=yanam
# Retrieve Weather Parameters for: tura,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=tura
# Retrieve Weather Parameters for: ilulissat,gl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ilulissat
# Retrieve Weather Parameters for: celestun,mx
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=celestun
# Retrieve Weather Parameters for: svetlyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=svetlyy
# Retrieve Weather Parameters for: termiz,uz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=termiz
# Retrieve Weather Parameters for: saucillo,mx
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=saucillo
# Retrieve Weather Parameters for: alofi,nu
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=alofi
# Retrieve Weather Parameters for: kapuskasing,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kapuskasing
# Retrieve Weather Parameters for: halifax,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=halifax
# Retrieve Weather Parameters for: puerto escondido,mx
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=puerto%20escondido
# Retrieve Weather Parameters for: georgetown,sh
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=georgetown
# Retrieve Weather Parameters for: gorontalo,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=gorontalo
# Retrieve Weather Parameters for: pangnirtung,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=pangnirtung
# Retrieve Weather Parameters for: green river,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=green%20river
# Retrieve Weather Parameters for: illoqqortoormiut,gl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=illoqqortoormiut
# Retrieve Weather Parameters for: port blair,in
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=port%20blair
# Retrieve Weather Parameters for: champerico,gt
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=champerico
# Retrieve Weather Parameters for: bethel,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=bethel
# Retrieve Weather Parameters for: buraydah,sa
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=buraydah
# Retrieve Weather Parameters for: letterkenny,ie
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=letterkenny
# Retrieve Weather Parameters for: thompson,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=thompson
# Retrieve Weather Parameters for: mys shmidta,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mys%20shmidta
# Retrieve Weather Parameters for: kilindoni,tz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kilindoni
# Retrieve Weather Parameters for: kjollefjord,no
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kjollefjord
# Retrieve Weather Parameters for: constitucion,cl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=constitucion
# Retrieve Weather Parameters for: ambagarh chauki,in
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ambagarh%20chauki
# Retrieve Weather Parameters for: lincoln,ar
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=lincoln
# Retrieve Weather Parameters for: itaueira,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=itaueira
# Retrieve Weather Parameters for: vicente guerrero,mx
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=vicente%20guerrero
# Retrieve Weather Parameters for: karratha,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=karratha
# Retrieve Weather Parameters for: kita,ml
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kita
# Retrieve Weather Parameters for: carutapera,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=carutapera
# Retrieve Weather Parameters for: payo,ph
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=payo
# Retrieve Weather Parameters for: nemuro,jp
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=nemuro
# Retrieve Weather Parameters for: laurel,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=laurel
# Retrieve Weather Parameters for: aguimes,es
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=aguimes
# Retrieve Weather Parameters for: kamina,cd
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kamina
# Retrieve Weather Parameters for: ekhabi,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ekhabi
# Retrieve Weather Parameters for: zhezkazgan,kz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=zhezkazgan
# Retrieve Weather Parameters for: vostok,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=vostok
# Retrieve Weather Parameters for: asfi,ma
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=asfi
# Retrieve Weather Parameters for: luorong,cn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=luorong
# Retrieve Weather Parameters for: ruatoria,nz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ruatoria
# Retrieve Weather Parameters for: carauari,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=carauari
# Retrieve Weather Parameters for: port alfred,za
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=port%20alfred
# Retrieve Weather Parameters for: creel,mx
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=creel
# Retrieve Weather Parameters for: taolanaro,mg
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=taolanaro
# Retrieve Weather Parameters for: barkly west,za
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=barkly%20west
# Retrieve Weather Parameters for: ucluelet,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ucluelet
# Retrieve Weather Parameters for: revelstoke,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=revelstoke
# Retrieve Weather Parameters for: norman wells,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=norman%20wells
# Retrieve Weather Parameters for: rancho palos verdes,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=rancho%20palos%20verdes
# Retrieve Weather Parameters for: nuuk,gl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=nuuk
# Retrieve Weather Parameters for: shache,cn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=shache
# Retrieve Weather Parameters for: daniel flores,cr
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=daniel%20flores
# Retrieve Weather Parameters for: lebu,cl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=lebu
# Retrieve Weather Parameters for: eufaula,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=eufaula
# Retrieve Weather Parameters for: buzhakan,am
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=buzhakan
# Retrieve Weather Parameters for: nouna,bf
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=nouna
# Retrieve Weather Parameters for: puerto colombia,co
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=puerto%20colombia
# Retrieve Weather Parameters for: saint-pierre,pm
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=saint-pierre
# Retrieve Weather Parameters for: samusu,ws
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=samusu
# Retrieve Weather Parameters for: fukue,jp
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=fukue
# Retrieve Weather Parameters for: dois corregos,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=dois%20corregos
# Retrieve Weather Parameters for: sitka,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=sitka
# Retrieve Weather Parameters for: ambodifototra,mg
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ambodifototra
# Retrieve Weather Parameters for: rudbar,af
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=rudbar
# Retrieve Weather Parameters for: ponta do sol,pt
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ponta%20do%20sol
# Retrieve Weather Parameters for: metro,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=metro
# Retrieve Weather Parameters for: road town,vg
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=road%20town
# Retrieve Weather Parameters for: laguna,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=laguna
# Retrieve Weather Parameters for: kabare,cd
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kabare
# Retrieve Weather Parameters for: nayoro,jp
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=nayoro
# Retrieve Weather Parameters for: batemans bay,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=batemans%20bay
# Retrieve Weather Parameters for: pulo,ph
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=pulo
# Retrieve Weather Parameters for: itacoatiara,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=itacoatiara
# Retrieve Weather Parameters for: baglung,np
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=baglung
# Retrieve Weather Parameters for: clyde river,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=clyde%20river
# Retrieve Weather Parameters for: anori,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=anori
# Retrieve Weather Parameters for: brae,gb
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=brae
# Retrieve Weather Parameters for: luderitz,na
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=luderitz
# Retrieve Weather Parameters for: hithadhoo,mv
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=hithadhoo
# Retrieve Weather Parameters for: talnakh,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=talnakh
# Retrieve Weather Parameters for: belyy yar,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=belyy%20yar
# Retrieve Weather Parameters for: moscow,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=moscow
# Retrieve Weather Parameters for: lagoa,pt
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=lagoa
# Retrieve Weather Parameters for: bambous virieux,mu
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=bambous%20virieux
# Retrieve Weather Parameters for: east london,za
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=east%20london
# Retrieve Weather Parameters for: carnarvon,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=carnarvon
# Retrieve Weather Parameters for: longlac,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=longlac
# Retrieve Weather Parameters for: gamba,ga
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=gamba
# Retrieve Weather Parameters for: medicine hat,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=medicine%20hat
# ...
# Retrieve Weather Parameters for: hambantota,lk
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=hambantota
# Retrieve Weather Parameters for: preston,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=preston
# Retrieve Weather Parameters for: savannah bight,hn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=savannah%20bight
# Retrieve Weather Parameters for: saint-francois,gp
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=saint-francois
# Retrieve Weather Parameters for: balakhninskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=balakhninskiy
# Retrieve Weather Parameters for: abu kamal,sy
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=abu%20kamal
# Retrieve Weather Parameters for: touros,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=touros
# Retrieve Weather Parameters for: honningsvag,no
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=honningsvag
# Retrieve Weather Parameters for: helong,cn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=helong
# Retrieve Weather Parameters for: bolungarvik,is
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=bolungarvik
# Retrieve Weather Parameters for: gilbues,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=gilbues
# Retrieve Weather Parameters for: barabai,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=barabai
# Retrieve Weather Parameters for: lhokseumawe,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=lhokseumawe
# Retrieve Weather Parameters for: palabuhanratu,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=palabuhanratu
# Retrieve Weather Parameters for: bintulu,my
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=bintulu
# Retrieve Weather Parameters for: souillac,mu
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=souillac
# Retrieve Weather Parameters for: belushya guba,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=belushya%20guba
# Retrieve Weather Parameters for: sembakung,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=sembakung
# Retrieve Weather Parameters for: luba,gq
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=luba
# Retrieve Weather Parameters for: san cristobal,ec
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=san%20cristobal
# Retrieve Weather Parameters for: pinawa,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=pinawa
# Retrieve Weather Parameters for: astana,kz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=astana
# Retrieve Weather Parameters for: namibe,ao
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=namibe
# Retrieve Weather Parameters for: vila,vu
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=vila
# Retrieve Weather Parameters for: moussoro,td
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=moussoro
# Retrieve Weather Parameters for: victoria,sc
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=victoria
# Retrieve Weather Parameters for: scottsbluff,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=scottsbluff
# Retrieve Weather Parameters for: aykhal,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=aykhal
# Retrieve Weather Parameters for: galesong,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=galesong
# Retrieve Weather Parameters for: hopkinsville,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=hopkinsville
# Retrieve Weather Parameters for: punta alta,ar
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=punta%20alta
# Retrieve Weather Parameters for: hailey,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=hailey
# Retrieve Weather Parameters for: thanh hoa,vn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=thanh%20hoa
# Retrieve Weather Parameters for: dikson,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=dikson
# Retrieve Weather Parameters for: carlsbad,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=carlsbad
# Retrieve Weather Parameters for: tuktoyaktuk,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=tuktoyaktuk
# Retrieve Weather Parameters for: dianopolis,br
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=dianopolis
# Retrieve Weather Parameters for: guerrero negro,mx
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=guerrero%20negro
# Retrieve Weather Parameters for: bababe,mr
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=bababe
# Retrieve Weather Parameters for: mandan,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mandan
# Retrieve Weather Parameters for: riyadh,sa
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=riyadh
# Retrieve Weather Parameters for: kutum,sd
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kutum
# Retrieve Weather Parameters for: katobu,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=katobu
# Retrieve Weather Parameters for: torbay,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=torbay
# Retrieve Weather Parameters for: jamestown,sh
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=jamestown
# Retrieve Weather Parameters for: quatre cocos,mu
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=quatre%20cocos
# Retrieve Weather Parameters for: rafai,cf
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=rafai
# Retrieve Weather Parameters for: sarh,td
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=sarh
# Retrieve Weather Parameters for: san vicente,ph
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=san%20vicente
# Retrieve Weather Parameters for: obala,cm
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=obala
# Retrieve Weather Parameters for: inirida,co
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=inirida
# Retrieve Weather Parameters for: stephenville,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=stephenville
# Retrieve Weather Parameters for: udarnyy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=udarnyy
# Retrieve Weather Parameters for: mazamari,pe
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mazamari
# Retrieve Weather Parameters for: vaitupu,wf
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=vaitupu
# Retrieve Weather Parameters for: saint george,bm
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=saint%20george
# Retrieve Weather Parameters for: iqaluit,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=iqaluit
# Retrieve Weather Parameters for: taoudenni,ml
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=taoudenni
# Retrieve Weather Parameters for: kualakapuas,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kualakapuas
# Retrieve Weather Parameters for: dingle,ie
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=dingle
# Retrieve Weather Parameters for: abasolo,mx
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=abasolo
# Retrieve Weather Parameters for: pemba,mz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=pemba
# Retrieve Weather Parameters for: mantua,cu
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mantua
# Retrieve Weather Parameters for: kuching,my
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kuching
# Retrieve Weather Parameters for: the valley,ai
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=the%20valley
# Retrieve Weather Parameters for: dunedin,nz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=dunedin
# Retrieve Weather Parameters for: ariano irpino,it
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=ariano%20irpino
# Retrieve Weather Parameters for: haicheng,cn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=haicheng
# Retrieve Weather Parameters for: yaan,cn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=yaan
# Retrieve Weather Parameters for: tiarei,pf
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=tiarei
# Retrieve Weather Parameters for: vancouver,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=vancouver
# Retrieve Weather Parameters for: vila franca do campo,pt
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=vila%20franca%20do%20campo
# Retrieve Weather Parameters for: lucapa,ao
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=lucapa
# Retrieve Weather Parameters for: alencon,fr
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=alencon
# Retrieve Weather Parameters for: russell,nz
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=russell
# Retrieve Weather Parameters for: vardo,no
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=vardo
# Retrieve Weather Parameters for: kampot,kh
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kampot
# Retrieve Weather Parameters for: saldanha,za
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=saldanha
# Retrieve Weather Parameters for: hobart,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=hobart
# Retrieve Weather Parameters for: saint-esteve,fr
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=saint-esteve
# Retrieve Weather Parameters for: haines junction,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=haines%20junction
# Retrieve Weather Parameters for: punta arenas,cl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=punta%20arenas
# Retrieve Weather Parameters for: kendari,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kendari
# Retrieve Weather Parameters for: altoona,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=altoona
# Retrieve Weather Parameters for: qaanaaq,gl
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=qaanaaq
# Retrieve Weather Parameters for: bac lieu,vn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=bac%20lieu
# Retrieve Weather Parameters for: bull savanna,jm
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=bull%20savanna
# Retrieve Weather Parameters for: omsukchan,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=omsukchan
# Retrieve Weather Parameters for: lata,sb
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=lata
# Retrieve Weather Parameters for: muros,es
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=muros
# Retrieve Weather Parameters for: berlevag,no
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=berlevag
# Retrieve Weather Parameters for: kapaa,us
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=kapaa
# Retrieve Weather Parameters for: saint-philippe,re
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=saint-philippe
# Retrieve Weather Parameters for: dongsheng,cn
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=dongsheng
# Retrieve Weather Parameters for: leningradskiy,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=leningradskiy
# Retrieve Weather Parameters for: dicabisagan,ph
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=dicabisagan
# Retrieve Weather Parameters for: padang,id
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=padang
# Retrieve Weather Parameters for: gimli,ca
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=gimli
# Retrieve Weather Parameters for: mayumba,ga
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=mayumba
# Retrieve Weather Parameters for: dubbo,au
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=dubbo
# Retrieve Weather Parameters for: turan,ru
# http://api.openweathermap.org/data/2.5/weather?appid=17fecf0e16c0b9b7cc36e73b9d35a158&units=imperial&q=turan

# %%
#Exception Handling
# What should I do if I can't retrieve information ....Drop na's cities.
city_coordinates_df2 = city_coordinates_df.dropna()

initial_df_sz= city_coordinates_df.shape[0]
final_df_sz= city_coordinates_df2.shape[0]

if initial_df_sz > final_df_sz:
    print("Oops, we couldn't retrieve the weather parameters for (%s) cities" %(initial_df_sz - final_df_sz))
    print("Your new DataFrame has the weather information for (%s) unique cities"%(final_df_sz))
    print('The DataFrame has been saved as WeatherPy2.csv')
    city_coordinates_df2.to_csv("WeatherPy2.csv")
else:
    print("We succesfully retrieve the weather information for all the random cities sample you requested")
    print('The DataFrame has been saved as WeatherPy.csv')
    city_coordinates_df2.to_csv("WeatherPy.csv")
# Out:
# Oops, we couldn't retrieve the weather parameters for (55) cities
# Your new DataFrame has the weather information for (445) unique cities
# The DataFrame has been saved as WeatherPy2.csv

# %%
city_coordinates_df2
# Out:
#                       City Country Code  Latitude  Longitude  Temperature  \
# 0                 kirakira           sb    -10.46     161.92        79.86
# 1                nishihara           jp     35.74     139.53        64.40
# 2             kruisfontein           za    -34.00      24.73        56.55
# 3           elizabeth city           us     36.30     -76.22        53.60
# 4                  te anau           nz    -45.41     167.72        52.95
# 5                cunduacan           mx     18.07     -93.17        78.80
# 6             komsomolskiy           ru     67.55      63.78        12.54
# 7                      mao           td     19.55     -71.08        75.20
# 9                    hobyo           so      5.35      48.53        76.80
# 10                   roald           no     62.58       6.12        46.40
# 11            port hedland           au    -20.31     118.58       102.20
# 12          ribeira grande           pt     38.52     -28.70        61.68
# 13                progreso           mx    -34.68     -56.22        68.00
# 14                coracora           pe    -15.02     -73.78        42.96
# 15               sahibganj           in     25.24      87.63        84.99
# 17                cherskiy           ru     68.75     161.30        32.61
# 18              carinhanha           br    -14.30     -43.77        73.11
# 19   los llanos de aridane           es     28.66     -17.92        64.40
# 20                 samarai           pg    -10.62     150.67        82.11
# 21            christchurch           nz    -43.53     172.64        59.00
# 22                flinders           au    -34.58     150.85        73.40
# 24                 kavieng           pg     -2.57     150.80        86.16
# 25           mbanza-ngungu           cd     -5.25      14.87        71.67
# 26            jacareacanga           br     -6.22     -57.76        73.74
# 27                   izumo           jp     35.37     132.75        64.40
# 28                    nome           us     30.04     -94.42        60.80
# 29                   opuwo           na    -18.06      13.84        54.57
# 30                 jiuquan           cn     39.73      98.49        40.44
# 32                frontera           mx     18.53     -92.64        78.80
# 33               lambarene           ga     -0.70      10.22        75.27
# ..                     ...          ...       ...        ...          ...
# 469              vancouver           ca     45.63    -122.67        64.40
# 470   vila franca do campo           pt     37.72     -25.43        59.00
# 471                 lucapa           ao     -8.42      20.74        61.86
# 472                alencon           fr     48.43       0.08        53.60
# 473                russell           nz    -33.01     -68.80        69.80
# 474                  vardo           no     39.62     -77.74        57.20
# 475                 kampot           kh     10.62     104.18        90.48
# 476               saldanha           za     41.42      -6.55        46.92
# 477                 hobart           au    -42.88     147.33        68.00
# 478           saint-esteve           fr     42.71       2.84        55.40
# 479        haines junction           ca     60.75    -137.51        32.79
# 480           punta arenas           cl    -53.16     -70.91        37.40
# 481                kendari           id     -3.99     122.52        80.40
# 482                altoona           us     40.52     -78.39        55.40
# 483                qaanaaq           gl     77.48     -69.36        19.11
# 485           bull savanna           jm     17.89     -77.59        74.64
# 486              omsukchan           ru     62.53     155.80        28.65
# 487                   lata           sb     30.78      78.62        56.10
# 488                  muros           es     42.77      -9.06        50.00
# 489               berlevag           no     70.86      29.09        32.00
# 490                  kapaa           us     22.08    -159.32        77.00
# 491         saint-philippe           re     45.36     -73.48        46.40
# 492              dongsheng           cn     29.72     112.52        59.79
# 493          leningradskiy           ru     69.38     178.42        19.11
# 494            dicabisagan           ph     17.08     122.42        79.59
# 495                 padang           id     -0.92     100.36        80.49
# 496                  gimli           ca     50.63     -96.99        49.17
# 497                mayumba           ga     -3.44      10.65        78.06
# 498                  dubbo           au    -32.25     148.60        77.00
# 499                  turan           ru     52.15      93.92        51.87
#
#      Humidity  Cloudiness  Wind Speed
# 0       100.0        92.0       14.23
# 1        72.0        75.0        6.93
# 2        93.0        12.0        3.27
# 3        76.0         1.0        4.70
# 4        81.0         0.0        9.42
# 5        83.0        40.0        4.70
# 6        84.0        80.0        9.31
# 7        88.0        75.0        4.70
# 9        98.0        24.0        5.28
# 10      100.0        76.0        4.70
# 11       15.0         0.0       11.41
# 12      100.0         0.0        4.16
# 13       94.0        90.0        2.24
# 14      100.0        76.0        2.15
# 15       49.0         0.0        4.61
# 17       81.0        12.0        3.38
# 18       62.0        12.0       10.98
# 19       77.0        76.0        6.93
# 20      100.0        80.0        9.42
# 21       54.0         0.0       10.29
# 22       53.0        20.0        4.70
# 24      100.0        12.0        3.38
# 25       96.0        64.0        1.70
# 26       95.0         0.0        2.15
# 27       77.0        75.0       19.46
# 28       77.0         1.0        4.70
# 29       52.0         0.0        2.71
# 30      100.0        88.0        3.71
# 32       83.0        40.0        4.70
# 33       95.0        20.0        2.48
# ..        ...         ...         ...
# 469      33.0         1.0        9.17
# 470      82.0        75.0        8.05
# 471      85.0         8.0        2.59
# 472      81.0         0.0        5.82
# 473      49.0        20.0        9.17
# 474      58.0         1.0        4.61
# 475      69.0         0.0        4.38
# 476      93.0         0.0        4.83
# 477      40.0         0.0        8.05
# 478      87.0         0.0        3.36
# 479      80.0        68.0        3.94
# 480     100.0        40.0        4.70
# 481     100.0        92.0        3.49
# 482      26.0         1.0        5.06
# 483      84.0        68.0        4.94
# 485      81.0        48.0        5.17
# 486      87.0         8.0        4.05
# 487      51.0         0.0        2.04
# 488     100.0        90.0        6.93
# 489     100.0        75.0        6.93
# 490      88.0        75.0       12.75
# 491      33.0         1.0        4.70
# 492      97.0        88.0       16.69
# 493      97.0         8.0       15.68
# 494     100.0        44.0        2.93
# 495     100.0        68.0        2.71
# 496      59.0         0.0       13.00
# 497     100.0        92.0        2.82
# 498      38.0         0.0        8.05
# 499      55.0        12.0        1.48
#
# [445 rows x 8 columns]

# %%
print('----------1. Latitude vs Longitude Scatterplot----------')
# Temperature vs Latitude 

#Build a scatter plot for Latitude vs. Temperature

plt.scatter(city_coordinates_df2["Longitude"], 
            city_coordinates_df2["Latitude"], c=city_coordinates_df2["Latitude"],
            edgecolor="black", linewidths=1, marker="o",
            cmap='Spectral_r', alpha=0.8, label="City")

plt.suptitle('Latitude vs Longitude')
plt.title('Total cities plotted = %s'%(final_df_sz))
plt.ylim(-180, 180)
plt.xlim(-90, 90)
plt.axvline(0, color='lightgray',alpha=0.4)
plt.savefig("=Latitude vs Longitude.png")
plt.show()
# Out:
# ----------1. Latitude vs Longitude Scatterplot----------

# %%
print('----------1. Temperature vs. Latitude Scatterplot----------')
# Temperature vs Latitude 
city_coordinates_df2.plot(kind="scatter",x="Latitude",y="Temperature",s=35, marker = 'o', color = 'red', grid=True)
plt.suptitle('Temperature (F) vs. Latitude')
plt.title('Total cities plotted = %s'%(final_df_sz))
plt.ylim(city_coordinates_df2['Temperature'].min() - 10, 10 + city_coordinates_df2['Temperature'].max())
plt.xlim(-90, 90)
plt.axvline(0, color='gray',alpha=0.4)
plt.savefig("Temperature vs. Latitude.png")
plt.show()
# Out:
# ----------1. Temperature vs. Latitude Scatterplot----------

# %%
print('----------2. Humidity vs. Latitude Scatterplot----------')
# Temperature vs Latitude 
city_coordinates_df2.plot(kind="scatter",x="Latitude",y="Humidity",s=35, marker = 'o', color = 'gold', grid=True)
plt.suptitle('Humidity vs. Latitude')
plt.title('Total cities plotted = %s'%(final_df_sz))
plt.ylim(city_coordinates_df2['Humidity'].min() - 5, 5 + city_coordinates_df2['Humidity'].max())
plt.xlim(-90, 90)
plt.axvline(0, color='gray',alpha=0.4)
plt.savefig("Humidity vs. Latitude.png")
plt.show()
# Out:
# ----------2. Humidity vs. Latitude Scatterplot----------

# %%
print('----------3. Cloudiness vs. Latitude Scatterplot----------')
# Temperature vs Latitude 
city_coordinates_df2.plot(kind="scatter",x="Latitude",y="Cloudiness",s=50, marker = 'o', color = 'blue', grid=True)
plt.suptitle('Cloudiness (mph) vs. Latitude')
plt.title('Total cities plotted = %s'%(final_df_sz))
plt.ylim(city_coordinates_df2['Cloudiness'].min() - 10, 10 + city_coordinates_df2['Cloudiness'].max())
plt.xlim(-90, 90)
plt.axvline(0, color='gray',alpha=0.4)
plt.savefig("Cloudiness vs. Latitude.png")
plt.show()
# Out:
# ----------3. Cloudiness vs. Latitude Scatterplot----------

# %%
print('----------4. Wind Speed vs. Latitude Scatterplot----------')
# Temperature vs Latitude 
city_coordinates_df2.plot(kind="scatter",x="Latitude",y="Wind Speed",s=35, marker = 'o', color = 'green', grid=True)
plt.suptitle('Wind Speed (mph) vs. Latitude')
plt.title('Total cities plotted = %s'%(final_df_sz))
plt.ylim(0, 10 + city_coordinates_df2['Wind Speed'].max())
plt.xlim(-90, 90)
plt.axvline(0, color='gray',alpha=0.4)
plt.savefig("Wind Speed vs. Latitude.png")
plt.show()
# Out:
# ----------4. Wind Speed vs. Latitude Scatterplot----------

# %%
print('Observable Trends')
print('1.The temperature increases as coordinates get closer to the equator. The cities around the equator have the highest temperatures')
max_wind = city_coordinates_df2.loc[city_coordinates_df2['Wind Speed'] == city_coordinates_df2['Wind Speed'].max()]
max_wind['City']
max_wind['Country Code']
print('2.The wind speed for most of the cities is under 10 mph. The median is %smph. There is a possible outlier with a wind speed of %smph in %s'%(city_coordinates_df2['Wind Speed'].median(),city_coordinates_df2['Wind Speed'].max(),'Pahrump in the US'))
print('3. The clouds seem pretty disperse, whithout a visible correlation with the latitude.')
# Out:
# Observable Trends
# 1.The temperature increases as coordinates get closer to the equator. The cities around the equator have the highest temperatures
# 2.The wind speed for most of the cities is under 10 mph. The median is 6.22mph. There is a possible outlier with a wind speed of 39.15mph in Pahrump in the US
# 3. The clouds seem pretty disperse, whithout a visible correlation with the latitude.
